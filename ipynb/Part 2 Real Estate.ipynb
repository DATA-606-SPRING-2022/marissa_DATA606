# %%
import pandas as pd

# %% [markdown]
# # Real Estate - realtor.com
# Acknowledgement Maede Maftouni of Kaggle. Link as follow https://www.kaggle.com/maedemaftouni/us-real-estate-market-trends-visualization
#
# ## 1.1 Read Real Estate Inventory

# %%
df_RE = pd.read_csv('https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_County_History.csv')
df_RE.tail(5)
# Out:
# C:\Users\Pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,1,37,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                         month_date_yyyymm  \
# 207509                                             201607
# 207510                                             201607
# 207511                                             201607
# 207512                                             201607
# 207513  quality_flag = 1:  year-over-year figures may ...
#
#                                               county_fips      county_name  \
# 207509                                              18105       monroe, in
# 207510                                              45031   darlington, sc
# 207511                                              37131  northampton, nc
# 207512                                              29213        taney, mo
# 207513   please contact economics@realtor.com for more...              NaN
#
#         median_listing_price  median_listing_price_mm  \
# 207509              205000.0                      NaN
# 207510              139900.0                      NaN
# 207511              189900.0                      NaN
# 207512              149900.0                      NaN
# 207513                   NaN                      NaN
#
#         median_listing_price_yy  active_listing_count  \
# 207509                      NaN                 816.0
# 207510                      NaN                 262.0
# 207511                      NaN                  94.0
# 207512                      NaN                 908.0
# 207513                      NaN                   NaN
#
#         active_listing_count_mm  active_listing_count_yy  \
# 207509                      NaN                      NaN
# 207510                      NaN                      NaN
# 207511                      NaN                      NaN
# 207512                      NaN                      NaN
# 207513                      NaN                      NaN
#
#         median_days_on_market  ...  average_listing_price  \
# 207509                   72.0  ...               289096.0
# 207510                   99.0  ...               171710.0
# 207511                  143.0  ...               279266.0
# 207512                  118.0  ...               202261.0
# 207513                    NaN  ...                    NaN
#
#         average_listing_price_mm  average_listing_price_yy  \
# 207509                       NaN                       NaN
# 207510                       NaN                       NaN
# 207511                       NaN                       NaN
# 207512                       NaN                       NaN
# 207513                       NaN                       NaN
#
#         total_listing_count  total_listing_count_mm  total_listing_count_yy  \
# 207509                853.0                     NaN                     NaN
# 207510                265.0                     NaN                     NaN
# 207511                 94.0                     NaN                     NaN
# 207512                917.0                     NaN                     NaN
# 207513                  NaN                     NaN                     NaN
#
#         pending_ratio  pending_ratio_mm  pending_ratio_yy  quality_flag
# 207509         0.0466               NaN               NaN           NaN
# 207510         0.0115               NaN               NaN           NaN
# 207511         0.0106               NaN               NaN           NaN
# 207512         0.0110               NaN               NaN           NaN
# 207513            NaN               NaN               NaN           NaN
#
# [5 rows x 40 columns]

# %%
# The last row is a note and was dropped
df_RE.drop(df_RE.tail(1).index, inplace=True)

# %%
df_RE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207513 entries, 0 to 207512
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        207513 non-null  object
#  1   county_fips                              207513 non-null  object
#  2   county_name                              207513 non-null  object
#  3   median_listing_price                     207483 non-null  float64
#  4   median_listing_price_mm                  170228 non-null  float64
#  5   median_listing_price_yy                  169415 non-null  float64
#  6   active_listing_count                     207483 non-null  float64
#  7   active_listing_count_mm                  170154 non-null  float64
#  8   active_listing_count_yy                  169293 non-null  float64
#  9   median_days_on_market                    207513 non-null  float64
#  10  median_days_on_market_mm                 170249 non-null  float64
#  11  median_days_on_market_yy                 169434 non-null  float64
#  12  new_listing_count                        207486 non-null  float64
#  13  new_listing_count_mm                     145713 non-null  float64
#  14  new_listing_count_yy                     145090 non-null  float64
#  15  price_increased_count                    207486 non-null  float64
#  16  price_increased_count_mm                 47857 non-null   float64
#  17  price_increased_count_yy                 48261 non-null   float64
#  18  price_reduced_count                      207486 non-null  float64
#  19  price_reduced_count_mm                   133400 non-null  float64
#  20  price_reduced_count_yy                   136496 non-null  float64
#  21  pending_listing_count                    186128 non-null  float64
#  22  pending_listing_count_mm                 151358 non-null  float64
#  23  pending_listing_count_yy                 143288 non-null  float64
#  24  median_listing_price_per_square_foot     207039 non-null  float64
#  25  median_listing_price_per_square_foot_mm  169929 non-null  float64
#  26  median_listing_price_per_square_foot_yy  168916 non-null  float64
#  27  median_square_feet                       207039 non-null  float64
#  28  median_square_feet_mm                    169929 non-null  float64
#  29  median_square_feet_yy                    168916 non-null  float64
#  30  average_listing_price                    207483 non-null  float64
#  31  average_listing_price_mm                 170228 non-null  float64
#  32  average_listing_price_yy                 169415 non-null  float64
#  33  total_listing_count                      207486 non-null  float64
#  34  total_listing_count_mm                   170260 non-null  float64
#  35  total_listing_count_yy                   169398 non-null  float64
#  36  pending_ratio                            186124 non-null  float64
#  37  pending_ratio_mm                         152742 non-null  object
#  38  pending_ratio_yy                         145775 non-null  object
#  39  quality_flag                             170563 non-null  float64
# dtypes: float64(35), object(5)
# memory usage: 64.9+ MB

# %%
# The dates needs to be formatted to month, dates, and years.
change = {'month_date_yyyymm': int} 
df_RE = df_RE.astype(change)

# %%
df_RE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207513 entries, 0 to 207512
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        207513 non-null  int32
#  1   county_fips                              207513 non-null  object
#  2   county_name                              207513 non-null  object
#  3   median_listing_price                     207483 non-null  float64
#  4   median_listing_price_mm                  170228 non-null  float64
#  5   median_listing_price_yy                  169415 non-null  float64
#  6   active_listing_count                     207483 non-null  float64
#  7   active_listing_count_mm                  170154 non-null  float64
#  8   active_listing_count_yy                  169293 non-null  float64
#  9   median_days_on_market                    207513 non-null  float64
#  10  median_days_on_market_mm                 170249 non-null  float64
#  11  median_days_on_market_yy                 169434 non-null  float64
#  12  new_listing_count                        207486 non-null  float64
#  13  new_listing_count_mm                     145713 non-null  float64
#  14  new_listing_count_yy                     145090 non-null  float64
#  15  price_increased_count                    207486 non-null  float64
#  16  price_increased_count_mm                 47857 non-null   float64
#  17  price_increased_count_yy                 48261 non-null   float64
#  18  price_reduced_count                      207486 non-null  float64
#  19  price_reduced_count_mm                   133400 non-null  float64
#  20  price_reduced_count_yy                   136496 non-null  float64
#  21  pending_listing_count                    186128 non-null  float64
#  22  pending_listing_count_mm                 151358 non-null  float64
#  23  pending_listing_count_yy                 143288 non-null  float64
#  24  median_listing_price_per_square_foot     207039 non-null  float64
#  25  median_listing_price_per_square_foot_mm  169929 non-null  float64
#  26  median_listing_price_per_square_foot_yy  168916 non-null  float64
#  27  median_square_feet                       207039 non-null  float64
#  28  median_square_feet_mm                    169929 non-null  float64
#  29  median_square_feet_yy                    168916 non-null  float64
#  30  average_listing_price                    207483 non-null  float64
#  31  average_listing_price_mm                 170228 non-null  float64
#  32  average_listing_price_yy                 169415 non-null  float64
#  33  total_listing_count                      207486 non-null  float64
#  34  total_listing_count_mm                   170260 non-null  float64
#  35  total_listing_count_yy                   169398 non-null  float64
#  36  pending_ratio                            186124 non-null  float64
#  37  pending_ratio_mm                         152742 non-null  object
#  38  pending_ratio_yy                         145775 non-null  object
#  39  quality_flag                             170563 non-null  float64
# dtypes: float64(35), int32(1), object(4)
# memory usage: 64.1+ MB

# %%
# Formatting to Date column
df_RE['month_date_yyyymm'] = pd.to_datetime(df_RE['month_date_yyyymm'], format = '%Y%m')
df_RE.rename(columns={'month_date_yyyymm':'date'}, inplace = True)
df_RE.sample(5)
# Out:
#              date county_fips           county_name  median_listing_price  \
# 36461  2021-02-01        8013           boulder, co              930500.0
# 134302 2018-06-01       13059            clarke, ga              239900.0
# 107960 2019-03-01       19115            louisa, ia              159143.0
# 196285 2016-10-01       19165            shelby, ia              125000.0
# 41772  2020-12-01       22033  east baton rouge, la              279950.0
#
#         median_listing_price_mm  median_listing_price_yy  \
# 36461                    0.0586                   0.4120
# 134302                  -0.0105                   0.2398
# 107960                   0.1429                   0.2731
# 196285                      NaN                      NaN
# 41772                    0.0000                   0.1667
#
#         active_listing_count  active_listing_count_mm  \
# 36461                  384.0                  -0.1847
# 134302                 589.0                   0.0948
# 107960                  29.0                   0.0000
# 196285                  57.0                      NaN
# 41772                 1371.0                  -0.0419
#
#         active_listing_count_yy  median_days_on_market  ...  \
# 36461                   -0.5362                   60.0  ...
# 134302                   0.0370                   52.0  ...
# 107960                  -0.2927                   77.0  ...
# 196285                      NaN                  120.0  ...
# 41772                   -0.3841                   87.0  ...
#
#         average_listing_price  average_listing_price_mm  \
# 36461               1464335.0                    0.0440
# 134302               317427.0                   -0.0085
# 107960               148718.0                    0.0617
# 196285               148117.0                       NaN
# 41772                396773.0                    0.0161
#
#         average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 36461                     0.3059               1067.0                  0.0420
# 134302                    0.1517                824.0                  0.0123
# 107960                    0.1103                 33.0                 -0.0294
# 196285                       NaN                 61.0                     NaN
# 41772                     0.2046               2234.0                 -0.0688
#
#         total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 36461                  -0.3753         1.7813             0.622
# 134302                  0.1508         0.3956           -0.1118
# 107960                 -0.2979         0.1379            -0.069
# 196285                     NaN         0.0702               NaN
# 41772                  -0.2070         0.6295           -0.0407
#
#         pending_ratio_yy  quality_flag
# 36461             0.7148           1.0
# 134302            0.1438           0.0
# 107960           -0.0084           1.0
# 196285               NaN           NaN
# 41772             0.3644           0.0
#
# [5 rows x 40 columns]

# %%
# Extracting the Year and Month from the date
df_RE['month']= df_RE['date'].dt.month
df_RE['year']= df_RE['date'].dt.year
df_RE.sample(5)
# Out:
#              date county_fips     county_name  median_listing_price  \
# 104552 2019-04-01        8091       ouray, co              698500.0
# 156292 2017-11-01       42041  cumberland, pa              229800.0
# 140800 2018-04-01        8121  washington, co              220000.0
# 94179  2019-07-01       41037        lake, or              169900.0
# 82644  2019-11-01       48241      jasper, tx              173000.0
#
#         median_listing_price_mm  median_listing_price_yy  \
# 104552                  -0.0394                  -0.0127
# 156292                   0.0266                   0.0585
# 140800                   0.5172                   1.3158
# 94179                   -0.0286                   0.0825
# 82644                    0.0328                   0.1733
#
#         active_listing_count  active_listing_count_mm  \
# 104552                 141.0                   0.0292
# 156292                 890.0                  -0.1721
# 140800                  10.0                   0.6667
# 94179                   55.0                  -0.0179
# 82644                  365.0                  -0.0712
#
#         active_listing_count_yy  median_days_on_market  ...  \
# 104552                   0.0217                  143.0  ...
# 156292                  -0.2559                   80.0  ...
# 140800                   2.3333                   18.0  ...
# 94179                    0.1458                   89.0  ...
# 82644                    0.3931                  105.0  ...
#
#         average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 104552                   -0.0521                155.0                  0.0544
# 156292                    0.0324                906.0                 -0.4147
# 140800                    1.0401                 18.0                  0.2857
# 94179                    -0.1373                 56.0                 -0.0345
# 82644                     0.1834                385.0                 -0.0700
#
#         total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 104552                  0.1071         0.0922            0.0192
# 156292                 -0.4575         0.0169           -0.4213
# 140800                  2.0000         0.8000           -0.5333
# 94179                   0.1200         0.0182            0.0003
# 82644                   0.3140         0.0575            0.0066
#
#         pending_ratio_yy  quality_flag  month  year
# 104552            0.0777           0.0      4  2019
# 156292           -0.3828           1.0     11  2017
# 140800              -0.2           1.0      4  2018
# 94179            -0.0027           0.0      7  2019
# 82644             -0.057           1.0     11  2019
#
# [5 rows x 42 columns]

# %%
# The county fips needs to fill 5 codes and change object to string
df_RE.rename(columns={'county_fips': 'FIPS'}, inplace=True)
df_RE['FIPS'] = df_RE['FIPS'].astype('str')
df_RE['FIPS'] = df_RE['FIPS'].apply(lambda x: x.zfill(5))

# %%
# The county name needs to be separated.
# County should be title case. State should be all caps
df_RE[['county', 'state']] = df_RE.county_name.str.split(',', expand=True)
df_RE['state']= df_RE['state'].str.lstrip().str.upper()
df_RE['county']= df_RE['county'].str.title()
df_RE.sample(5)
# Out:
#              date   FIPS       county_name  median_listing_price  \
# 207187 2016-07-01  13087       decatur, ga              139900.0
# 119050 2018-11-01  05081  little river, ar              129000.0
# 141623 2018-04-01  17107         logan, il              109000.0
# 167333 2017-08-01  26145       saginaw, mi              119700.0
# 23199  2021-06-01  38097        traill, nd              172250.0
#
#         median_listing_price_mm  median_listing_price_yy  \
# 207187                      NaN                      NaN
# 119050                  -0.1342                   0.3096
# 141623                   0.0000                   0.4533
# 167333                   0.0067                   0.0887
# 23199                    0.4366                   0.1522
#
#         active_listing_count  active_listing_count_mm  \
# 207187                 143.0                      NaN
# 119050                  24.0                   0.0435
# 141623                 153.0                  -0.0129
# 167333                 831.0                   0.0627
# 23199                   21.0                   1.6250
#
#         active_listing_count_yy  median_days_on_market  ...  \
# 207187                      NaN                  156.0  ...
# 119050                  -0.3143                   79.0  ...
# 141623                  -0.1730                  120.0  ...
# 167333                  -0.2255                   53.0  ...
# 23199                   -0.4167                   19.0  ...
#
#         total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 207187                     NaN                     NaN         0.0070
# 119050                  0.0435                 -0.3143            NaN
# 141623                  0.0780                 -0.0596         0.4510
# 167333                  0.0670                 -0.2103         0.0349
# 23199                   0.5652                 -0.2941         0.7619
#
#         pending_ratio_mm  pending_ratio_yy  quality_flag  month  year  \
# 207187               NaN               NaN           NaN      7  2016
# 119050               NaN               NaN           1.0     11  2018
# 141623            0.1284            0.2077           1.0      4  2018
# 167333            0.0042            0.0153           0.0      8  2017
# 23199            -1.1131            0.3175           1.0      6  2021
#
#               county  state
# 207187       Decatur     GA
# 119050  Little River     AR
# 141623         Logan     IL
# 167333       Saginaw     MI
# 23199         Traill     ND
#
# [5 rows x 44 columns]

# %%
df_RE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207513 entries, 0 to 207512
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   date                                     207513 non-null  datetime64[ns]
#  1   FIPS                                     207513 non-null  object
#  2   county_name                              207513 non-null  object
#  3   median_listing_price                     207483 non-null  float64
#  4   median_listing_price_mm                  170228 non-null  float64
#  5   median_listing_price_yy                  169415 non-null  float64
#  6   active_listing_count                     207483 non-null  float64
#  7   active_listing_count_mm                  170154 non-null  float64
#  8   active_listing_count_yy                  169293 non-null  float64
#  9   median_days_on_market                    207513 non-null  float64
#  10  median_days_on_market_mm                 170249 non-null  float64
#  11  median_days_on_market_yy                 169434 non-null  float64
#  12  new_listing_count                        207486 non-null  float64
#  13  new_listing_count_mm                     145713 non-null  float64
#  14  new_listing_count_yy                     145090 non-null  float64
#  15  price_increased_count                    207486 non-null  float64
#  16  price_increased_count_mm                 47857 non-null   float64
#  17  price_increased_count_yy                 48261 non-null   float64
#  18  price_reduced_count                      207486 non-null  float64
#  19  price_reduced_count_mm                   133400 non-null  float64
#  20  price_reduced_count_yy                   136496 non-null  float64
#  21  pending_listing_count                    186128 non-null  float64
#  22  pending_listing_count_mm                 151358 non-null  float64
#  23  pending_listing_count_yy                 143288 non-null  float64
#  24  median_listing_price_per_square_foot     207039 non-null  float64
#  25  median_listing_price_per_square_foot_mm  169929 non-null  float64
#  26  median_listing_price_per_square_foot_yy  168916 non-null  float64
#  27  median_square_feet                       207039 non-null  float64
#  28  median_square_feet_mm                    169929 non-null  float64
#  29  median_square_feet_yy                    168916 non-null  float64
#  30  average_listing_price                    207483 non-null  float64
#  31  average_listing_price_mm                 170228 non-null  float64
#  32  average_listing_price_yy                 169415 non-null  float64
#  33  total_listing_count                      207486 non-null  float64
#  34  total_listing_count_mm                   170260 non-null  float64
#  35  total_listing_count_yy                   169398 non-null  float64
#  36  pending_ratio                            186124 non-null  float64
#  37  pending_ratio_mm                         152742 non-null  object
#  38  pending_ratio_yy                         145775 non-null  object
#  39  quality_flag                             170563 non-null  float64
#  40  month                                    207513 non-null  int64
#  41  year                                     207513 non-null  int64
#  42  county                                   207513 non-null  object
#  43  state                                    207513 non-null  object
# dtypes: datetime64[ns](1), float64(35), int64(2), object(6)
# memory usage: 71.2+ MB

# %%
# Sorting records by State, County, and Date in ascending order
df_RE = df_RE.sort_values(by = ['state', 'county', 'date'], ascending = (True, True, True)).reset_index(drop = True)
df_RE.head(5)
# Out:
#         date   FIPS         county_name  median_listing_price  \
# 0 2016-07-01  02013  aleutians east, ak              485000.0
# 1 2016-08-01  02013  aleutians east, ak              485000.0
# 2 2016-09-01  02013  aleutians east, ak              485000.0
# 3 2016-10-01  02013  aleutians east, ak              199500.0
# 4 2016-11-01  02013  aleutians east, ak              485000.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                      NaN                      NaN                   3.0
# 1                      NaN                      NaN                   4.0
# 2                      NaN                      NaN                   4.0
# 3                      NaN                      NaN                   4.0
# 4                      NaN                      NaN                   4.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 0                      NaN                      NaN                  612.0
# 1                      NaN                      NaN                  644.0
# 2                      NaN                      NaN                  665.0
# 3                      NaN                      NaN                  449.0
# 4                      NaN                      NaN                  735.0
#
#    ...  total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 0  ...                     NaN                     NaN            NaN
# 1  ...                     NaN                     NaN            NaN
# 2  ...                     NaN                     NaN            NaN
# 3  ...                     NaN                     NaN            NaN
# 4  ...                     NaN                     NaN            NaN
#
#    pending_ratio_mm  pending_ratio_yy  quality_flag  month  year  \
# 0               NaN               NaN           NaN      7  2016
# 1               NaN               NaN           NaN      8  2016
# 2               NaN               NaN           NaN      9  2016
# 3               NaN               NaN           NaN     10  2016
# 4               NaN               NaN           NaN     11  2016
#
#            county  state
# 0  Aleutians East     AK
# 1  Aleutians East     AK
# 2  Aleutians East     AK
# 3  Aleutians East     AK
# 4  Aleutians East     AK
#
# [5 rows x 44 columns]

# %%
df_RE.to_csv('Real_Estate.csv', index=False)
